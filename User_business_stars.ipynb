# %%
#Read 3 files
import pandas as pd
from io import StringIO
from IPython.display import display

business = pd.read_csv ('business.csv', sep=',')
business.drop(business.columns[[0]],axis=1,inplace=True)
user = pd.read_csv ('user.csv', sep=',')
review = pd.read_csv ('review.csv',sep=',')

# %%
review.head()
user.head()
# Out:
#                   user_id       Name  review_count  average_stars
# 0  18kPq7GPye-YQ3LyKyAZPw     Russel           108           4.14
# 1  rpOyqD_893cqmDAtJLbdog     Jeremy          1292           3.67
# 2  4U9kSBLuBDU391x6bxU-YA    Michael           395           3.68
# 3  fHtTaujcyKvXglE33Z5yIw        Ken            11           4.64
# 4  SIBCL7HBkrP4llolm4SC2A  Katherine            66           3.80

# %%
#Merge
m = user.merge(review,on='user_id')
m_sub = m[['user_id','business_id','stars']]
m_sub
# Out:
#                         user_id             business_id  stars
# 0        18kPq7GPye-YQ3LyKyAZPw  HdODbQJU0D814XdwBxXRfw      5
# 1        rpOyqD_893cqmDAtJLbdog  iW-vB9UD89solHK8mhB4lA      4
# 2        rpOyqD_893cqmDAtJLbdog  9OImDAJVdml2lhOAxmq4sQ      3
# 3        rpOyqD_893cqmDAtJLbdog  m4Al9hIg_6Xkk9Zr_q9aTQ      4
# 4        rpOyqD_893cqmDAtJLbdog  EXw9XBNT5VSlFPBQ07pQXA      4
# 5        rpOyqD_893cqmDAtJLbdog  442pYCJeVzpxovoa7kx-bQ      4
# 6        rpOyqD_893cqmDAtJLbdog  rMZOMR3SvZJt4DwO2NaUFA      4
# 7        rpOyqD_893cqmDAtJLbdog  _Y5m_KLBMs7GHipGa9yxWQ      4
# 8        rpOyqD_893cqmDAtJLbdog  7726OI-tv7f2MUohXfsbeQ      4
# 9        rpOyqD_893cqmDAtJLbdog  IVzUfZ8s7ygIrYoZi9WKOg      5
# 10       rpOyqD_893cqmDAtJLbdog  ETRdmj8x54HhzT2yc_E85Q      4
# 11       rpOyqD_893cqmDAtJLbdog  zYKhrC_VgTwqfTqIECM4Yw      2
# 12       rpOyqD_893cqmDAtJLbdog  tw7hGp3m6iXZQccTd7JBhQ      3
# 13       rpOyqD_893cqmDAtJLbdog  g2dQ8zJV5lki1zDfGm82tQ      2
# ...
